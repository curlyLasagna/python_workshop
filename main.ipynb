# %% [markdown]
# # Funnier == more attractive?
# We have a csv file containing a list of pick up lines, alongside it's humor rating and the number of dates users have reported in obtaining after using said pick up line
#
# > This data is all made up btw. I have negative rizz.
# >
# > Meanwhile, my man Newton will not save any for the rest of us

# %% [markdown]
# ## Importing dependencies
#
# We'll be using [pandas](https://pandas.pydata.org/) and matplotlib to plot a dataset to find insights
#
# The `%matplotlib inline` magic command enables plots to show within this browser window

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Reading in our dataset
#
# ### Reading csv
# We'll use pandas `read_csv()` function to read the csv I've provided
#
# ### Viewing the data
# The `head(n)` function will list the first top n rows will be printed

# %%
data = pd.read_csv('./pickup_lines.csv')

pd.set_option("display.max.columns", None)
data.head(20)
# Out:
#                                           pickup_line  humor_rating  \
# 0   Are you wi-fi? Cause I'm totally feeling a con...             8
# 1   If I had a nickel for every time I saw someone...             7
# 2   I'd like to take you to the movies, but they d...             6
# 3   Are you Australian? Because you meet all of my...             9
# 4                    Know what's on the menu? Me-N-U.             5
# 5   Your middle name must be Gillette. Because you...             4
# 6   You look so familiar. Didn't we take a class t...             9
# 7   You and I are like nachos with jalapeños. I'm ...             8
# 8   Knock-knock. (Who's there?) When where? (When ...             3
# 9   Do you like Star Wars? Cause Yoda only one for...             7
# 10  Go ahead, feel my shirt. It's made of boyfrien...             5
# 11   If you were a Transformer you'd be Optimus Fine!             8
# 12  Do you believe in love at first sight, or shou...             6
# ...

# %% [markdown]
# ## Plotting with matplotlib
#
# The `plot()` function

# %%
spacing = np.linspace(0, 200)
plt.title('Are funny pickup lines better?')
plt.plot(data['humor_rating'], label="Humor rating")
plt.plot(data['successful_dates'], label="Dates")
plt.legend(loc="upper left")
plt.axis('off')
# Out:
# (np.float64(-3.7), np.float64(77.7), np.float64(2.4), np.float64(15.6))

# %% [markdown]
# Looking at the graph, we can see a direct relation with how funny a pick up line is with the number of dates that reported
